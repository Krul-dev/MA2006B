# %% [markdown]
# # Protocolo de Encriptación RSA
#
# En este notebook, mostraremos el proceso de encriptación utilizando el protocolo ElGamal. Empezaremos por cargar las funciones que necesitamos:

# %%
import sys
import importlib.util

if 'google.colab' in sys.modules:
    runtime = "Google Colab"
    if importlib.util.find_spec("cryptocalc") is None:
        print("   Installing MA2006B from GitHub\n")
        # !pip install git+https://github.com/Krul-dev/MA2006B.git
else:
    runtime = "Local environment"

import cryptocalc

print(f"\n========= Notebook execution context =========")
print(f"              Runtime: {runtime}")
print(f"       Python version: {sys.version.split()[0]}")
print(f"   CryptoCalc version: {cryptocalc.__version__}")

from cryptocalc import (
    elgamal_key_generation,
    rsa_encryption,
    rsa_decryption,
    encode,
    decode,
)
# Out:
# ========= Notebook execution context =========
#               Runtime: Local environment
#        Python version: 3.14.2
#    CryptoCalc version: 0.1.0

# %% [markdown]
# Una vez que ya hemos cargado las librerías necesarias, empezamos por generar nuestras llaves *pública* y *privada*

# %%
(public_key, private_key) = elgamal_key_generation(1000)

# %% [markdown]
# Mostramos ahora la llave privada que generamos. En la práctica, es muy importante que esta información no se divulgue.

# %%
private_key
# Out:
# ...

# %% [markdown]
# La llave pública, por otro lado, se debe de compartir con las partes interesadas, afín de que puedan encriptar sus mensajes. En este caso la llave pública a compartir es:

# %%
public_key
# Out:
# (...,
#  ...)

# %% [markdown]
# Para demostrar como funciona este proceso, procedemos ahora a generar un mensaje que deseamos encriptar. Empezaremos con el simple 'Hello World!'

# %%
plain_text = 'Hello World!'

# %% [markdown]
# Antes de poder encriptar este mensaje, necesitamos codificarlo en forma numérica:

# %%
plain_message = encode(plain_text)
plain_message
# Out:
# 10334410032597741434076685640

# %% [markdown]
# Utilizando la llave pública, podemos ahora generar el *mensaje encriptado*

# %%
encrypted_message = rsa_encryption(public_key, plain_message)
encrypted_message
# Out:
# ...

# %% [markdown]
# Si este mensaje fuera interceptado por un adversario (digamos Eva) este sería el mensaje de texto que obtendría:

# %%
encrypted_text = decode(encrypted_message)
encrypted_text
# Out:
# '\x15\x9e)Ä\x97µ\x86ñ)\x15g\x88òGT¼\x89ÍeªëþOâ\x9f8øáw\x08`Ò%+[Ì\x0eÑjAåZ¤ôHÕÙVÄrëxx§Fqã\x13\xa0uuô\x1a\x1f/³\x84Ø}z\x96Ç\x86þ|%\x15\x1fP\x18\x10¤õ)f\x07/jú\xadDh0í\x9f¸X\x8a\x88O ¶\x1aõSb\x1eå\x90ôz7\x9dfõ\x99¾Ò\x0f\x0eê\x8e\x12?ë[áUöCW\x11\x88ÞÔ®>,X¯=\x93ÃD+sÚ\x0bP\x98\x15³:7OB\x1b3²\x93\x80Êú\x84\x88ã!º;Ó\x9cØ£ý\x8b0Á\x8cæTÆ\x8aÜ\x15Òþ\x98\x87w\x80ý<û½°ä"f\x82jÒ)óZÌ\x93C\x80ÇviÎ\x93|\x00Þæ\x01\x9d\x04äý\x99Íá\x13\x80E5\x98¤è¡Ö\x9e~s¡\x8ffÜÃ»^D\x86ÔØÌE'

# %% [markdown]
# Por otro lado, Alicia al momento de recibir este mensaje podría desencriptarlo primero utilizando su llave pública:

# %%
decrypted_message = rsa_decryption(public_key,private_key, encrypted_message)
decrypted_message
# Out:
# 10334410032597741434076685640

# %% [markdown]
# Para poder leer este mensaje basta con decodificarlo a mensaje de texto:

# %%
decrypted_text = decode(decrypted_message)
decrypted_text
# Out:
# 'Hello World!'
