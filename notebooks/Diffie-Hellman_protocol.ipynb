# %% [markdown]
# # Protocolo Diffie-Hellman para la generación de una llave compartida
#
# En este notebook, mostraremos el proceso de generar una llave compartida utilizando el protocolo Diffie-Hellman. Empezaremos por cargar las funciones que necesitamos:

# %%
import sys
import importlib.util

if 'google.colab' in sys.modules:
    runtime = "Google Colab"
    if importlib.util.find_spec("cryptocalc") is None:
        print("   Installing MA2006B from GitHub\n")
        # !pip install git+https://github.com/Krul-dev/MA2006B.git
else:
    runtime = "Local environment"

import cryptocalc

print(f"\n========= Notebook execution context =========")
print(f"              Runtime: {runtime}")
print(f"       Python version: {sys.version.split()[0]}")
print(f"   CryptoCalc version: {cryptocalc.__version__}")

from cryptocalc import (
    RFC_3526_SAFE_PRIME,
    RFC_3526_SOPHIE_PRIME,
    generate_private_key,
    diffie_hellman_public_key_generator,
    diffie_hellman_shared_key_generator
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#       9 else:
#      10     runtime = "Local environment"
# ---> 12 import cryptocalc
#      14 print(f"\n========= Notebook execution context =========")
#      15 print(f"              Runtime: {runtime}")
#
# File ~/Dropbox/Mathematics/Coding Projects/Python Projects/MA2006B/src/cryptocalc/__init__.py:42
#      27 from cryptocalc.ecc import (
#      28     jacobi_symbol,
#      29     discriminant,
#    (...)     34     points_of_elliptic_curve,
#      35 )
#      37 from cryptocalc.diffie_hellman import (
#      38     diffie_hellman_public_key_generator,
#      39     diffie_hellman_shared_key_generator,
#      40 )
# ---> 42 from rfc_specification import (
#      43     RFC_3526_SAFE_PRIME,
#      44     RFC_3526_SOPHIE_PRIME,
#      45     generate_private_key,
#      46 )
#      48 from cryptocalc.rsa_cryptography import (
#      49     rsa_key_generation,
#      50     rsa_encryption,
#    (...)     53     rsa_text_decryption,
#      54 )
#      56 from cryptocalc.encoding import (
#      57     encode,
#      58     decode,
#      59 )
#
# ModuleNotFoundError: No module named 'rfc_specification'

# %% [markdown]
# Para este ejemplo, utilizaremos uno de los primos seguros listados en la especificación [RFC 3526](https://www.ietf.org/rfc/rfc3526.txt) y generaremos las llaves secretas de Alicia y Beto de manera aleatoria:

# %%
p = RFC_3526_SAFE_PRIME
q = RFC_3526_SOPHIE_PRIME
g = 2
a = generate_private_key(q)
b = generate_private_key(q)

print(f"Primo Seguro (p): {p}\n")
print(f"Primo de Sophie Germain (q): {q}\n")
print(f"Generador (g): {g}\n")
print(f"Llave privada de Alicia (a): {a}\n")
print(f"Llave privada de Beto (b): {b}")
# Out:
# Primo Seguro (p): 1552518092300708935130918131258481755631334049434514313202351194902966239949102107258669453876591642442910007680288864229150803718918046342632727613031282983744380820890196288509170691316593175367469551763119843371637221007211169123
#
# Primo de Sophie Germain (q): 776259046150354467565459065629240877815667024717257156601175597451483119974551053629334726938295821221455003840144432114575401859459023171316363806515641491872190410445098144254585345658296587683734775881559921685818610503605584561
#
# Generador (g): 2
#
# Llave privada de Alicia (a): 654787349875376301498653242639876342321582528915083286277654681125370678840928215799308713209748163527322017043213904199043357536043876821803104926674106112263127293000011386820324103432360273233626399420006080517696741242314964419
#
# Llave privada de Beto (b): 226357769473682978597611526168259633413171832232709305655188939842667201858075801720996837758888692286993195112537844233290169529344599855503198660725201491776221883308111662261613642707252575194912297215006973269957689164699222591

# %% [markdown]
# Generamos ahora las llaves públicas de Alicia y Beto:

# %%
A = diffie_hellman_public_key_generator(p, g, a)
B = diffie_hellman_public_key_generator(p, g, b)

print(f"Llave pública de Alicia (A): {A}\n")
print(f"Llave pública de Beto (B): {B}")
# Out:
# Llave pública de Alicia (A): 1020301055336198026936857249647540969846383233175827427923392049633974758771542951926241231147863421226880123532985957701278659882397069788874429120270984334775443335346753211386191108307090631798159561070288257242350350111418939050
#
# Llave pública de Beto (B): 792879849009672594796079381103635900381898362682614146118558573641197321034294161810865552904108528366688416600483953291983340053581971196883580826889205999806700182205086296068871092232537742376818861455274070437607014152520826224

# %% [markdown]
# Finalmente, generamos las llaves compartidas

# %%
s_a = diffie_hellman_shared_key_generator(p, B, a)
s_b = diffie_hellman_shared_key_generator(p, A, b)

print(f"Llave compartida generada por Alicia (s_a): {s_a}\n")
print(f"Llave compartida generada por Beto (s_b): {s_b}\n")
# Out:
# Llave compartida generada por Alicia (s_a): 1113754995338571899075258191726280368538177984001719605236941945845390900342098456532110741193941907139149345636299224647862737843517938182144300447188753676555050746124635313849340885894936037898503429573448235208413032818918612859
#
# Llave compartida generada por Beto (s_b): 1113754995338571899075258191726280368538177984001719605236941945845390900342098456532110741193941907139149345636299224647862737843517938182144300447188753676555050746124635313849340885894936037898503429573448235208413032818918612859

# %% [markdown]
# Como podemos observar, ambas llaves son iguales, lo cual ilustra la correción del protocolo.
