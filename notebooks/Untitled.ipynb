# %%
1+2
# Out:
# 3

# %%
from cryptocalc import (
   ...:     rsa_key_generation,
   ...:     rsa_encryption,
   ...:     rsa_decryption,
   ...:     encode,
   ...:     decode
   ...:     )

# %%
(public_key, private_key) = rsa_key_generation(1000)

# %%
public_key
# Out:
# (...,
#  ...)

# %%
encode("Hello World!!!")
# Out:
# 671944380693508444872280319485256
